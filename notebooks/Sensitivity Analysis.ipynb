# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import cPickle as cp
import matplotli

# %%
data = cp.load(open("../data/all_data_together.pkl"))

# %%
columns = data["COIL_88540102"].keys()

# %%
new_df = pd.DataFrame(columns=columns)

# %%
for i in columns:
    temp = []
    for j in data.keys():
#         print j 
#         print i
        temp.append(data[j][i])
    new_df[i] = temp

# %%
for col in new_df.columns:
    if col not in  ["AIM_QLTY", "COOLING_SEQ"]:
        new_df[col] = new_df[col].astype(float)

# %%
groups = new_df.groupby("AIM_QLTY").groups

# %%
groups
# Out:
# {'A12007': Int64Index([  358,  1887,  3403,  4819,  5512,  5910,  6139,  6593,  7022,
#               7690,  7834,  8004,  8458,  9956, 10118, 10300, 12387, 13851,
#              17500, 17962, 18592, 20168, 21065, 21626, 23884, 23906, 25345,
#              26468, 27633, 28334, 28718, 29106, 30275, 30452, 30878, 31017,
#              31382, 32586],
#             dtype='int64'),
#  'A12010': Int64Index([  108,  3341,  9325,  9484, 12146, 17693, 18791, 20584, 21346,
#              23824, 24274, 30003, 30163],
#             dtype='int64'),
#  'A19001': Int64Index([   74,    76,   148,   158,   184,   488,   590,  1050,  1162,
#               1253,
#              ...
#              30613, 31291, 31316, 31364, 31522, 31589, 31692, 32217, 32292,
#              32718],
#             dtype='int64', length=127),
#  'A20001': Int64Index([  256,   315,   327,   363,   481,   492,   514,   536,   714,
#                784,
#              ...
# ...

# %%
new_df.loc[groups["A12010"]].corr()
# Out:
#                 SLB_SOCKING_TM       FRT_AVG   RMET_P1_AVG         HR_ID  \
# SLB_SOCKING_TM    1.000000e+00 -2.957885e-01 -1.433759e-02 -8.448221e-01
# FRT_AVG          -2.957885e-01  1.000000e+00 -1.069085e-01  1.818320e-01
# RMET_P1_AVG      -1.433759e-02 -1.069085e-01  1.000000e+00 -3.430820e-01
# HR_ID            -8.448221e-01  1.818320e-01 -3.430820e-01  1.000000e+00
# NI                4.422544e-02 -2.978416e-01  5.807718e-01 -3.566973e-01
# SLB_RET_TM_MIN    9.979073e-01 -3.034344e-01  1.593242e-02 -8.596025e-01
# LYS               1.563958e-01 -3.496790e-01 -3.867111e-01  1.389437e-01
# RMET_P4_AVG      -1.093896e-01  2.434665e-01  2.470506e-01 -2.128053e-01
# NB                3.975939e-16 -9.794848e-15  6.549509e-16  1.233280e-13
# SI               -3.799869e-01 -3.301093e-01 -1.099532e-01  4.644719e-01
# TI                3.975939e-16 -9.794848e-15  6.549509e-16  1.233280e-13
# SDOT             -3.062486e-01  8.088515e-02  4.832809e-01  1.369478e-01
# ...

# %%
corr_mat["LYS"]
# Out:
# SLB_SOCKING_TM   -4.981983e-01
# FRT_AVG           3.528027e-01
# RMET_P1_AVG       1.481772e-01
# HR_ID            -6.403077e-01
# NI                2.390382e-01
# SLB_RET_TM_MIN    4.479940e-01
# LYS               1.000000e+00
# RMET_P4_AVG      -7.067246e-01
# NB                9.724897e-16
# SI                6.176862e-01
# TI                9.724897e-16
# SDOT             -3.581504e-02
# EL                1.844676e-02
# C                 4.640105e-01
# B                -9.724897e-16
# AL               -2.999047e-01
# RMET_P3_AVG      -4.406746e-01
# RMET_P6_AVG       1.493198e-01
# SEC1             -6.974655e-01
# P                 6.570154e-01
# S                 9.672917e-02
# CT_AVG            4.834166e-01
# V                 9.724897e-16
# CR                2.401523e-01
# F6_AVG            6.853012e-01
# CU               -5.514497e-01
# RMET_P7_AVG       5.119756e-02
# UTS               8.742284e-01
# MN                5.296338e-01
# RMET_P5_AVG       3.255944e-01
# ...

# %%
def
